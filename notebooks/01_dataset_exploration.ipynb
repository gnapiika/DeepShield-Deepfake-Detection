# %%
import os

real_path = "../dataset/raw/training_real"
fake_path = "../dataset/raw/training_fake"

print("Real Images:", len(os.listdir(real_path)))
print("Fake Images:", len(os.listdir(fake_path)))
# Out:
# Real Images: 1081
# Fake Images: 960

# %%
import cv2
import matplotlib.pyplot as plt
import os

real_path = "../dataset/raw/training_real"

img_name = os.listdir(real_path)[0]
img_path = os.path.join(real_path, img_name)

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.title("Real Image")
plt.axis("off")
plt.show()

# %%
fake_path = "../dataset/raw/training_fake"

img_name = os.listdir(fake_path)[0]
img_path = os.path.join(fake_path, img_name)

img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.title("Fake Image")
plt.axis("off")
plt.show()

# %%
real_path = "../dataset/raw/training_real"

img_name = os.listdir(real_path)[0]
img_path = os.path.join(real_path, img_name)

img = cv2.imread(img_path)

print("Image Shape:", img.shape)
# Out:
# Image Shape: (600, 600, 3)
